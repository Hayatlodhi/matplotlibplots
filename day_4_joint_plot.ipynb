# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np

import seaborn as sns
iris = sns.load_dataset("iris")
iris.head(1)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa

# %%
# make data
x = iris["petal_length"]
y = iris["petal_width"]

# %%
sns.jointplot("petal_width","petal_length", data=iris, kind="reg")
pass
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(x='petal_length',y='petal_width',data=iris)

# %%
# hex kind data
fig=sns.jointplot(x='petal_length',y='petal_width',kind='hex',data=iris)

# %%
# Kde kind data
sns.jointplot(x='petal_length',y='petal_width', data=iris, kind="kde",space=0,color='g')
pass

# %%
# kde plot with box
g = (sns.jointplot(x='petal_length',y='petal_width',data=iris, color="r").plot_joint(sns.kdeplot, zorder=0, n_levels=6))
