# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
iris = sns.load_dataset("iris")
plt.title("Sepal length of iris data set ")

plt.plot(iris["sepal_length"], "r--")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
